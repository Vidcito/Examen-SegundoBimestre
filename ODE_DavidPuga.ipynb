# %% [markdown]
# <a href="https://colab.research.google.com/github/Vidcito/Examen-SegundoBimestre/blob/main/ODE_DavidPuga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext autoreload

# %%
# %autoreload 2
from src import ODE_euler

# %%
import matplotlib.pyplot as plt

# Resolución del problema mediante el método de Euler
y_aprox, t, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

# Cálculo de la solución exacta
y_real = [(ti ** 2) + (1/3) * math.exp(-5 * ti) for ti in t]

plt.figure(figsize=(8, 5))
plt.plot(t, y_real, label="Y_real (Exacta)", linestyle="dashed", color="blue")
plt.plot(t, y_aprox, label="Y_aprox (Euler)", marker="o", color="red")
plt.xlabel("Tiempo t")
plt.ylabel("Y(t)")
plt.title("Comparación entre Y_real y Y_aprox")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Errores

# %%
# prompt: error relativos para n=10, 5 y 20 y y_real=10

import numpy as np

# Assuming y_real and y_aprox are already defined from previous code
# Example values (replace with your actual data)
# y_real = [10, 10, 10]  # Example, replace with actual y_real values
# y_aprox = [9, 11, 9.5]  # Example, replace with actual y_aprox values


# Error absoluto
errores_absolutos = np.abs(np.array(y_real) - np.array(y_aprox))

# Error relativo (usando y_real como valor de referencia)
# Manejar divisiones entre cero en caso de que y_real sea cero.
y_real_array = np.array(y_real)
errores_relativos = np.where(y_real_array !=0, np.abs(np.array(y_real) - np.array(y_aprox)) / np.abs(y_real_array), 0)


# Imprimir los errores relativos para N = 10, 5, y 20 (ajustar indices según tus arreglos)
# Asegúrate que los valores de N corresponden a los índices en tus arreglos.

# Ejemplo de como acceder a los elementos de las listas según N (ajusta los índices según tus datos)
# Asumiendo que tienes y_aprox y y_real definidos como listas.
# Se debe tener cuidado con los indices para que correspondan a la solución para n=10, 5, 20.
# Si tus arreglos de y_aprox y y_real se corresponden a un vector de tiempos t, necesitaras el índice correspondiente a cada tiempo.
# Si no se usa este ejemplo, asegúrese de cambiar la siguiente linea por la forma en que se calculan los errores para n=10,5,20.


print(f"Error relativo para n=10: {errores_relativos[0]}") # Ejemplo, cambiar indice 0.
print(f"Error relativo para n=5: {errores_relativos[1]}")  # Ejemplo, cambiar indice 1.
print(f"Error relativo para n=20: {errores_relativos[2]}") # Ejemplo, cambiar indice 2.
# Out:
# Error relativo para n=10: 0.0
# Error relativo para n=5: 0.21449188288003476
# Error relativo para n=20: 0.33385182368077276
